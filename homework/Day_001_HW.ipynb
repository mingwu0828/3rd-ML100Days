# %%
## HW.1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_squared_error(y, yp):
    mse = MSE = (sum((y - yp) ** 2) / len(y)) ** 0.5
    return mse

# %%
MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean absolute error is 11.319
# The Mean squared error is 14.574

# %%
## HW.2
## 2.1
## 1. 你選的這組資料為何重要
##   Corporación Favorita Grocery Sales Forecasting
##   零售商CorporaciónFavorita, 目前依靠主觀預測方法，期望透過機器學習找出正確時間並提供足夠產品來滿足客戶。
##   預測銷售練習對於零售業, 製造業都是每年重覆發生的問題
##   預測錯誤, 造成存貨成本的推積與壓力. 預測正確, 則製造順利. 客戶滿意度提升.
##   為下一次合作累積信譽. 
## 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
##   數據來自Favorita
##   培訓數據包括日期，商店和商品信息，是否正在推廣該商品以及單位銷售。其他文件包含可能對構建模型有用的補充信息。
## 3. 蒐集而來的資料型態為何
##   CSV格式資料, 屬於文字, 數值資料型態.
## 4. 這組資料想解決的問題如何評估
##   定義目標: 找出地區, 時間, 銷售產品, 數量, 銷售額的關係組合.

# %%
## HW.3
## 3.1
##   核心問題: 提升業績
##   定義: 在相同的人力與車輛資源下, 提高接單/載客時間, 降低空車時間, 提高營業額為目標.
## 3.2
##   提高載客率部分, 主要是在特定時段與地點組合, 快速掌握與接到客戶搭車需求.
##   所以蒐集車隊車輛的GPS數據與載客紀錄, 進行分析研究.
## 3.3
## 蒐集資料為座標數值資料與載客紀錄時間資料組合. 
## 3.4
##   追蹤觀察營業額數據成長狀況. 
##   因應時間與環境改變, 循環分析研究.
